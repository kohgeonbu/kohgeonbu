# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/1234.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x1050>

# %%
print(img.shape)
# Out:
# (1050, 700, 3)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
